# %% [markdown]
# # Ex - GroupBy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"

drinks = pd.read_csv(url)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
drinks['continent'] = np.where(drinks['country'].isin(['USA','Canada']), "NA", drinks['continent'])
drinks['continent'] = np.where(drinks['continent'].isnull(), "CA", drinks['continent'])
# drinks['continent'].fillna("CA",inplace=True)
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks[drinks['country'].isin(['Mexico','Canada'])]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 32   Canada            240              122            100
# 109  Mexico            238               68              5
#
#      total_litres_of_pure_alcohol continent
# 32                            8.2        NA
# 109                           5.5        CA

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# CA    136.000000
# EU    193.777778
# NA    244.500000
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks['continent'] = np.where(drinks['continent'].isin(['NA',"CA","SA"]), "A", drinks['continent'])
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# A     155.600000
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.groupby("continent")['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# A           35.0   37.514286  58.231471  1.0   4.0   11.0   40.50  221.0
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby("continent").mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# A             155.600000       148.257143      37.514286
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
#
#            total_litres_of_pure_alcohol
# continent
# A                              6.102857
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby("continent").median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# A                  159.0            124.0           11.0
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
#
#            total_litres_of_pure_alcohol
# continent
# A                                  6.30
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.

# %%
drinks.groupby("continent")['spirit_servings'].agg(['mean','min','max'])
# Out:
#                  mean  min  max
# continent
# A          148.257143   25  438
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254

# %%
drinks.groupby("continent")['spirit_servings'].agg(['mean',min,np.max, "median"])
# Out:
# continent
# A     124.0
# AF      3.0
# AS     16.0
# EU    122.0
# OC     37.0
# Name: spirit_servings, dtype: float64
